# %%
using JuMP, Gurobi, CSV, DataFrames

# Helper function to check if two flights (using their global indices) conflict in gate occupancy.
# If they are on the same tail number, we assume they are connected and thus not in conflict.
function conflicts(global_df, f1, f2, buffer_time)
    # Do not treat flights with the same tail as conflicting.
    if global_df.TailNumber[f1] == global_df.TailNumber[f2]
        return false
    end
    enter1 = global_df.ArrivalTimeMinutes[f1]
    exit1  = global_df.OffTimeMinutes[f1] + buffer_time
    enter2 = global_df.ArrivalTimeMinutes[f2]
    exit2  = global_df.OffTimeMinutes[f2] + buffer_time
    return (enter1 < exit2) && (enter2 < exit1)
end

function assign_gates(start_flight, end_flight, flights_per_save = 5, lookahead = 10, departing = true, arriving = true, connecting = true, buffer_time = 0)
    # Load Data
    df = CSV.read("Data/Final_Formatted_Sample_Day.csv", DataFrame)
    walking_distances = CSV.read("Data/Walking Distances Arriving and Departing Pax.csv", DataFrame)
    walking_distances_gate_to_gate = CSV.read("Data/Walking Distances Gate-to-Gate.csv", DataFrame)
    connections_matrix = CSV.read("Data/connections_matrix.csv", DataFrame)
    connections_tier_matrix = CSV.read("Data/connections_tier_matrix.csv", DataFrame) # (i,j) = tier of connection time between flight i and flight j
    # ^ tier 1: 0-45 minute layover | tier 2: 45-90 minute layover | tier 3: >90 minute layover

    # Sort df by time the aircraft enters a gate
    df = df[sortperm(df.ArrivalTimeMinutes), :]

    # Function that solves a single window (from global flight start_flight to end_flight)
    function assign_gates_single(start_flight, end_flight, departing = true, arriving = true, connecting = true, buffer_time = buffer_time, assignments_overall = Dict())
        """
        Solves the gate assignment for a window of flights.
        - start_flight and end_flight are global indices.
        - assignments_overall is a dictionary of locked assignments from previous windows.
        """
        num_flights = end_flight - start_flight + 1
        df_small = df[start_flight:end_flight, :]
        connections_matrix_small = connections_matrix[start_flight:end_flight, start_flight:end_flight]
        connections_tier_matrix_small = connections_tier_matrix[start_flight:end_flight, start_flight:end_flight]
        connections_tier_matrix_small[1:size(connections_tier_matrix_small,1), 1:size(connections_tier_matrix_small,2)-1] = Matrix(connections_tier_matrix_small[1:size(connections_tier_matrix_small,1), 2:end])

        # Build a connections time matrix (adjusted to window indices)
        T_f1_f2 = zeros(num_flights, num_flights)
        T_f1_f2[1:size(connections_matrix_small,1), 1:size(connections_matrix_small,2)-1] =
            Matrix(connections_matrix_small[1:size(connections_matrix_small,1), 2:end])
    
        # Define enter and exit gate times for the window
        df_small[!, :EnterGateTime] = df_small.ArrivalTimeMinutes
        df_small[!, :ExitGateTime]  = df_small.OffTimeMinutes

        # Separate arriving and departing flights (using the window's data)
        departing_indices = findall(df_small.IsDeparting .== "Y")
        arriving_indices  = findall(df_small.IsDeparting .== "N")
        F_dep = length(departing_indices)   # Number of departing flights in the window
        F_arr = length(arriving_indices)    # Number of arriving flights in the window
        F     = num_flights                 # Total flights in window
        G     = 96                          # Number of gates

        # Passenger counts (for objective function)
        P_df = [df_small.PassengersDept[departing_indices[f]] for f in 1:F_dep]
        P_af = [df_small.PassengersArr[arriving_indices[f]]  for f in 1:F_arr]
    
        # Walking distances parameters
        W_g = walking_distances.TSA_to_Gate     # From security to gate
        W_b = walking_distances.Gate_to_Bag       # From gate to baggage claim
        W_g1_g2 = Matrix(walking_distances_gate_to_gate)
    
        # -------------------------------
        # Define the Optimization Model
        # -------------------------------
        model = Model(Gurobi.Optimizer)
    
        # Decision variables: M[f, g] is 1 if flight f (local index) is assigned to gate g.
        @variable(model, M[1:F, 1:G], Bin)
    
        # Process connecting flight pairs (if enabled)
        connecting_pairs = Vector{Tuple{Int, Int}}()
        if connecting   
            # Pre-process connecting flight pairs
            for f1 in 1:F
                for f2 in 1:F
                    if connections_tier_matrix_small[f1, f2] == 1
                        push!(connecting_pairs, (f1, f2))
                    end
                end
            end
            # Auxiliary variables for linearizing M[f1,g1] * M[f2,g2]
            @variable(model, Z[connecting_pairs, 1:G, 1:G], Bin)
        end
    
        @objective(model, Min,
            departing * sum(W_g[g] * P_df[f] * M[departing_indices[f], g] for f in 1:F_dep, g in 1:G)
            + arriving * sum(W_b[g] * P_af[f] * M[arriving_indices[f], g] for f in 1:F_arr, g in 1:G)
            + connecting * sum(
                T_f1_f2[f1, f2] * W_g1_g2[g1, g2] * Z[(f1,f2), g1, g2]
                for (f1,f2) in connecting_pairs, g1 in 1:G, g2 in 1:G
            )
        )
    
        if connecting
            # Linearization constraints for product variables Z = M[f1, g1] * M[f2, g2]
            @constraints(model, begin
                [(f1, f2) in connecting_pairs, g1 in 1:G, g2 in 1:G], 
                    Z[(f1, f2), g1, g2] <= M[f1, g1]
                [(f1, f2) in connecting_pairs, g1 in 1:G, g2 in 1:G], 
                    Z[(f1, f2), g1, g2] <= M[f2, g2]
                [(f1, f2) in connecting_pairs, g1 in 1:G, g2 in 1:G], 
                    Z[(f1, f2), g1, g2] >= M[f1, g1] + M[f2, g2] - 1
            end)
        end
    
        # Each flight in the window must be assigned exactly one gate.
        @constraint(model, [f in 1:F], sum(M[f, g] for g in 1:G) == 1)

        # -------------------------------------------------------
        # Incorporate Locked Flight Information from Previous Windows
        # -------------------------------------------------------
        # For each flight that has been locked (with a gate) from previous windows,
        # we adjust the current window as follows.
        # (a) If a flight in the current window (global index = start_flight + local_f - 1)
        #     conflicts (in time) with the locked flight, then it cannot be assigned to the locked gate.
        # (b) If the flight in the current window should use the same gate as the locked flight
        #     (i.e. same tail and close timing), then force that assignment.
        for (global_locked, locked_gate) in assignments_overall
            for local_f in 1:F
                #global_local = start_flight + local_f - 1
                if conflicts(df, global_locked, local_f, buffer_time)
                    @constraint(model, M[local_f, locked_gate] == 0)
                end
            end
        end

        for (global_locked, locked_gate) in assignments_overall
            for local_f in 1:F
                # Here we use df_small for the current window flight,
                # while using df for the locked flight.
                if (df[global_locked, :].TailNumber == df_small.TailNumber[local_f]) &&
                   (df[global_locked, :].OffTimeMinutes + 120 >= df_small.ArrivalTimeMinutes[local_f])
                    @constraint(model, M[local_f, locked_gate] == 1)
                end
            end
        end

        # -------------------------------------------------------
        # Constraints Among Flights Within the Current Window
        # -------------------------------------------------------
        # Precompute conflict pairs (for flights that are on different aircraft)
        conflict_pairs = Vector{Tuple{Int, Int}}()
        for f1 in 1:(F-1)
            for f2 in (f1+1):F
                if df_small.TailNumber[f1] != df_small.TailNumber[f2]
                    enter1  = df_small.EnterGateTime[f1]
                    depart1 = df_small.ExitGateTime[f1] + buffer_time
                    enter2  = df_small.EnterGateTime[f2]
                    depart2 = df_small.ExitGateTime[f2] + buffer_time
                    if (enter1 < depart2) && (enter2 < depart1)
                        push!(conflict_pairs, (f1, f2))
                    end
                end
            end
        end
    
        # For every conflicting pair, ensure they are not assigned the same gate.
        for (f1, f2) in conflict_pairs
            for g in 1:G
                @constraint(model, M[f1, g] + M[f2, g] <= 1)
            end
        end
    
        # Precompute same‐gate pairs among local flights (arriving vs. departing)
        same_gate_pairs = Vector{Tuple{Int, Int}}()
        for f1 in arriving_indices
            for f2 in departing_indices
                if (df_small.TailNumber[f1] == df_small.TailNumber[f2]) &&
                   (df_small.ExitGateTime[f1] + 120 >= df_small.EnterGateTime[f2])
                    push!(same_gate_pairs, (f1, f2))
                end
            end
        end
    
        # Enforce that flights in a same‐gate pair share the same gate.
        for (f1, f2) in same_gate_pairs
            for g in 1:G
                @constraint(model, M[f1, g] == M[f2, g])
            end
        end
    
        # -------------------------------
        # Solve the Model
        # -------------------------------
        optimize!(model)
    
        # Extract assignments from the model (using local flight indices)
        assignments = Dict(f => g for f in 1:F, g in 1:G if value(M[f, g]) ≈ 1)
    
        return assignments
    end    

    # Compute the window size and prepare to collect overall assignments.
    flights_in_window = flights_per_save + lookahead
    assignments_overall = Dict()
    num_flights_overall = end_flight - start_flight + 1
    println("Flights locked per window: ", flights_per_save)

    # Slide the window over the global flight indices.
    for i in start_flight:flights_per_save:end_flight
        local_end = min(i + flights_in_window - 1, end_flight)
        local_assignments = assign_gates_single(i, local_end, departing, arriving, connecting, buffer_time, assignments_overall)
        println("Assigned gates for flights ", i, " to ", local_end)
        
        # Convert the local (window) assignment keys to global flight indices.
        global_assignments = Dict((k + i - 1) => v for (k, v) in local_assignments)
        println("Global assignments: ", global_assignments)
        
        # Lock in only the first flights_per_save flights from the current window.
        locked_in_assignments = Dict((k + i - 1) => v for (k, v) in local_assignments if k <= flights_per_save)
        println("Locked assignments for flights ", i, " to ", min(i + flights_per_save - 1, end_flight))
        println("Locked in assignments: ", locked_in_assignments)
        
        # Merge these locked assignments into the overall assignment dictionary.
        assignments_overall = merge(assignments_overall, locked_in_assignments)
    end

    # -------------------------------
    # Write Out Final Assignments
    # -------------------------------
    df[!, :OptDepGate] = Vector{Union{String, Missing}}(missing, nrow(df))
    df[!, :OptArrGate] = Vector{Union{String, Missing}}(missing, nrow(df))

    # Gate mapping (gate number to gate code)
    gate_mapping = Dict(
        1 => "A8", 2 => "A9", 3 => "A10", 4 => "A11", 5 => "A13", 
        6 => "A14", 7 => "A15", 8 => "A16", 9 => "A17", 10 => "A18", 
        11 => "A19", 12 => "A20", 13 => "A21", 14 => "A22", 15 => "A23", 
        16 => "A24", 17 => "A25", 18 => "A28", 19 => "A29", 20 => "A33", 
        21 => "A34", 22 => "A35", 23 => "A36", 24 => "A37", 25 => "A38", 
        26 => "A39", 27 => "B1", 28 => "B2", 29 => "B3", 30 => "B4", 
        31 => "B5", 32 => "B6", 33 => "B7", 34 => "B9", 35 => "B10", 
        36 => "B11", 37 => "B12", 38 => "B14", 39 => "B16", 40 => "B17", 
        41 => "B18", 42 => "B19", 43 => "B21", 44 => "B22", 45 => "B24", 
        46 => "B25", 47 => "B26", 48 => "B27", 49 => "B28", 50 => "B29", 
        51 => "B30", 52 => "B31", 53 => "B32", 54 => "B33", 55 => "B34", 
        56 => "B35", 57 => "B36", 58 => "B37", 59 => "B38", 60 => "B39", 
        61 => "B40", 62 => "B42", 63 => "B43", 64 => "B44", 65 => "B46", 
        66 => "B47", 67 => "B48", 68 => "B49", 69 => "C2", 70 => "C4", 
        71 => "C6", 72 => "C7", 73 => "C8", 74 => "C10", 75 => "C11", 
        76 => "C12", 77 => "C14", 78 => "C15", 79 => "C16", 80 => "C17", 
        81 => "C19", 82 => "C20", 83 => "C21", 84 => "C22", 85 => "C24", 
        86 => "C26", 87 => "C27", 88 => "C28", 89 => "C29", 90 => "C30", 
        91 => "C31", 92 => "C33", 93 => "C35", 94 => "C36", 95 => "C37", 
        96 => "C39"
    )
    println("Total flights: ", num_flights_overall)
    println("Total locked assignments: ", length(assignments_overall))
    println(assignments_overall)

    # Apply the locked assignments to the global dataframe.
    for f in start_flight:end_flight
        gate_number = get(assignments_overall, f, missing)
        if !ismissing(gate_number)
            gate_code = get(gate_mapping, gate_number, missing)
            if df.IsDeparting[f] == "Y"
                df[f, :OptDepGate] = gate_code
            else
                df[f, :OptArrGate] = gate_code
            end
        end
    end

    # Save only the window (or the full day, as desired)
    df_window = df[start_flight:end_flight, :]
    CSV.write("Optimized_Gate_Assignments_Sample_Day.csv", df_window)
end
# Out:
# assign_gates (generic function with 7 methods)

# %%
assign_gates(1, 1200, 1, 0, false, false, true)
# Out:
# Flights locked per window: 1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 27649 rows, 9312 columns and 64512 nonzeros
# Model fingerprint: 0x0ed03f47
# Variable types: 0 continuous, 9312 integer (9312 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 1 to 1
# Global assignments: Dict(1 => 50)
# Locked assignments for flights 1 to 1
# Locked in assignments: Dict(1 => 50)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1 rows, 96 columns and 96 nonzeros
# Model fingerprint: 0x5d524dce
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 2 to 2
# Global assignments: Dict(2 => 1)
# Locked assignments for flights 2 to 2
# Locked in assignments: Dict(2 => 1)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 3 to 3
# Global assignments: Dict(3 => 2)
# Locked assignments for flights 3 to 3
# Locked in assignments: Dict(3 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 4 to 4
# Global assignments: Dict(4 => 2)
# Locked assignments for flights 4 to 4
# Locked in assignments: Dict(4 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 5 to 5
# Global assignments: Dict(5 => 2)
# Locked assignments for flights 5 to 5
# Locked in assignments: Dict(5 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 6 to 6
# Global assignments: Dict(6 => 2)
# Locked assignments for flights 6 to 6
# Locked in assignments: Dict(6 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 7 to 7
# Global assignments: Dict(7 => 2)
# Locked assignments for flights 7 to 7
# Locked in assignments: Dict(7 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 8 to 8
# Global assignments: Dict(8 => 2)
# Locked assignments for flights 8 to 8
# Locked in assignments: Dict(8 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 9 to 9
# Global assignments: Dict(9 => 2)
# Locked assignments for flights 9 to 9
# Locked in assignments: Dict(9 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 10 to 10
# Global assignments: Dict(10 => 2)
# Locked assignments for flights 10 to 10
# Locked in assignments: Dict(10 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 11 to 11
# Global assignments: Dict(11 => 2)
# Locked assignments for flights 11 to 11
# Locked in assignments: Dict(11 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 12 to 12
# Global assignments: Dict(12 => 2)
# Locked assignments for flights 12 to 12
# Locked in assignments: Dict(12 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 13 to 13
# Global assignments: Dict(13 => 2)
# Locked assignments for flights 13 to 13
# Locked in assignments: Dict(13 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 14 to 14
# Global assignments: Dict(14 => 2)
# Locked assignments for flights 14 to 14
# Locked in assignments: Dict(14 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 15 to 15
# Global assignments: Dict(15 => 2)
# Locked assignments for flights 15 to 15
# Locked in assignments: Dict(15 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 16 to 16
# Global assignments: Dict(16 => 2)
# Locked assignments for flights 16 to 16
# Locked in assignments: Dict(16 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 17 to 17
# Global assignments: Dict(17 => 2)
# Locked assignments for flights 17 to 17
# Locked in assignments: Dict(17 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 18 to 18
# Global assignments: Dict(18 => 2)
# Locked assignments for flights 18 to 18
# Locked in assignments: Dict(18 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 19 to 19
# Global assignments: Dict(19 => 2)
# Locked assignments for flights 19 to 19
# Locked in assignments: Dict(19 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 20 to 20
# Global assignments: Dict(20 => 2)
# Locked assignments for flights 20 to 20
# Locked in assignments: Dict(20 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 21 to 21
# Global assignments: Dict(21 => 2)
# Locked assignments for flights 21 to 21
# Locked in assignments: Dict(21 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 22 to 22
# Global assignments: Dict(22 => 2)
# Locked assignments for flights 22 to 22
# Locked in assignments: Dict(22 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 23 to 23
# Global assignments: Dict(23 => 2)
# Locked assignments for flights 23 to 23
# Locked in assignments: Dict(23 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 24 to 24
# Global assignments: Dict(24 => 2)
# Locked assignments for flights 24 to 24
# Locked in assignments: Dict(24 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 25 to 25
# Global assignments: Dict(25 => 2)
# Locked assignments for flights 25 to 25
# Locked in assignments: Dict(25 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 26 to 26
# Global assignments: Dict(26 => 2)
# Locked assignments for flights 26 to 26
# Locked in assignments: Dict(26 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 27 to 27
# Global assignments: Dict(27 => 2)
# Locked assignments for flights 27 to 27
# Locked in assignments: Dict(27 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 28 to 28
# Global assignments: Dict(28 => 2)
# Locked assignments for flights 28 to 28
# Locked in assignments: Dict(28 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 29 to 29
# Global assignments: Dict(29 => 2)
# Locked assignments for flights 29 to 29
# Locked in assignments: Dict(29 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 30 to 30
# Global assignments: Dict(30 => 2)
# Locked assignments for flights 30 to 30
# Locked in assignments: Dict(30 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 31 to 31
# Global assignments: Dict(31 => 2)
# Locked assignments for flights 31 to 31
# Locked in assignments: Dict(31 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 32 to 32
# Global assignments: Dict(32 => 2)
# Locked assignments for flights 32 to 32
# Locked in assignments: Dict(32 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 33 to 33
# Global assignments: Dict(33 => 2)
# Locked assignments for flights 33 to 33
# Locked in assignments: Dict(33 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 34 to 34
# Global assignments: Dict(34 => 2)
# Locked assignments for flights 34 to 34
# Locked in assignments: Dict(34 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 35 to 35
# Global assignments: Dict(35 => 2)
# Locked assignments for flights 35 to 35
# Locked in assignments: Dict(35 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 36 to 36
# Global assignments: Dict(36 => 2)
# Locked assignments for flights 36 to 36
# Locked in assignments: Dict(36 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 37 to 37
# Global assignments: Dict(37 => 2)
# Locked assignments for flights 37 to 37
# Locked in assignments: Dict(37 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 38 to 38
# Global assignments: Dict(38 => 2)
# Locked assignments for flights 38 to 38
# Locked in assignments: Dict(38 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 39 to 39
# Global assignments: Dict(39 => 2)
# Locked assignments for flights 39 to 39
# Locked in assignments: Dict(39 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 40 to 40
# Global assignments: Dict(40 => 2)
# Locked assignments for flights 40 to 40
# Locked in assignments: Dict(40 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 41 to 41
# Global assignments: Dict(41 => 2)
# Locked assignments for flights 41 to 41
# Locked in assignments: Dict(41 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 42 to 42
# Global assignments: Dict(42 => 2)
# Locked assignments for flights 42 to 42
# Locked in assignments: Dict(42 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 43 to 43
# Global assignments: Dict(43 => 2)
# Locked assignments for flights 43 to 43
# Locked in assignments: Dict(43 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 44 to 44
# Global assignments: Dict(44 => 2)
# Locked assignments for flights 44 to 44
# Locked in assignments: Dict(44 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# ...
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 465 to 465
# Global assignments: Dict(465 => 2)
# Locked assignments for flights 465 to 465
# Locked in assignments: Dict(465 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 466 to 466
# Global assignments: Dict(466 => 2)
# Locked assignments for flights 466 to 466
# Locked in assignments: Dict(466 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 467 to 467
# Global assignments: Dict(467 => 2)
# Locked assignments for flights 467 to 467
# Locked in assignments: Dict(467 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 468 to 468
# Global assignments: Dict(468 => 2)
# Locked assignments for flights 468 to 468
# Locked in assignments: Dict(468 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 469 to 469
# Global assignments: Dict(469 => 2)
# Locked assignments for flights 469 to 469
# Locked in assignments: Dict(469 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 470 to 470
# Global assignments: Dict(470 => 2)
# Locked assignments for flights 470 to 470
# Locked in assignments: Dict(470 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 471 to 471
# Global assignments: Dict(471 => 2)
# Locked assignments for flights 471 to 471
# Locked in assignments: Dict(471 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 472 to 472
# Global assignments: Dict(472 => 2)
# Locked assignments for flights 472 to 472
# Locked in assignments: Dict(472 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 473 to 473
# Global assignments: Dict(473 => 2)
# Locked assignments for flights 473 to 473
# Locked in assignments: Dict(473 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 474 to 474
# Global assignments: Dict(474 => 2)
# Locked assignments for flights 474 to 474
# Locked in assignments: Dict(474 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights
# Excessive output truncated after 524870 bytes.
# 475 to 475
# Global assignments: Dict(475 => 2)
# Locked assignments for flights 475 to 475
# Locked in assignments: Dict(475 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 476 to 476
# Global assignments: Dict(476 => 2)
# Locked assignments for flights 476 to 476
# Locked in assignments: Dict(476 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 96 columns and 98 nonzeros
# Model fingerprint: 0xbbb8626b
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 477 to 477
# Global assignments: Dict(477 => 2)
# Locked assignments for flights 477 to 477
# Locked in assignments: Dict(477 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 478 to 478
# Global assignments: Dict(478 => 2)
# Locked assignments for flights 478 to 478
# Locked in assignments: Dict(478 => 2)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-27
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 96 columns and 97 nonzeros
# Model fingerprint: 0xd4a84d12
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 24, time in user-callback 0.00 sec
# Assigned gates for flights 479 to 479
# Global assignments: Dict(479 => 2)
# Locked assignments for flights 479 to 479
# Locked in assignments: Dict(479 => 2)
# "Optimized_Gate_Assignments_Sample_Day.csv"
